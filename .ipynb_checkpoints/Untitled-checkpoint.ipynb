# %%
import numpy as np
import os

# %%
file_path = "competition/train/coords/1E8S_1_C.npy"

# %%
np.set_printoptions(threshold=np.inf,  # Show all elements
                  linewidth=np.inf,    # Don't wrap lines
                  precision=3,         # Show 3 decimal places
                  suppress=True)       # Don't use scientific notation

# Load the array
array = np.load(file_path)

# %%
#print(array)

# %% [markdown]
# ### 1. Reconstruct the pdb file from npy and fasta file

# %%
# !python reconstruct_pdb.py --coords-dir cleanedoords  --seqs-dir competition/train/seqs --output-dir reconstructed_pdbs

# %% [markdown]
# ### 2. Restrictive extract loop sequence
# Cutoff 11.0 A

# %%
# !python rna_loop_extractor.py --source-dir reconstructed_pdbs --output-dir extracted_loops --distance-cutoff 11.0
